# %%
import pandas as pd
import missingno
import matplotlib.pyplot as plt
import folium # pip install folium
from folium.plugins import MarkerCluster

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv("globalterrorismdb_0718dist.csv", low_memory=False)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.997490   23.762728          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1        0.0          NaN             NaN
# 1     NaN      1      1      1        0.0          NaN             NaN
# 2     NaN      1      1      1        0.0          NaN             NaN
# 3     NaN      1      1      1        0.0          NaN             NaN
# 4     NaN      1      1      1       -9.0          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN           0     NaN
# 1       NaN    NaN          0.0          NaN          NaN           0     7.0
# 2       NaN    NaN          0.0          NaN          NaN           0     NaN
# 3       NaN    NaN          0.0          NaN          NaN           0     NaN
# 4       NaN    NaN          0.0          NaN          NaN           0     NaN
#
#    nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0       NaN      NaN        NaN           NaN     NaN         NaN
# 1       NaN      NaN        NaN           NaN     NaN         NaN
# 2       NaN      NaN        NaN           NaN     NaN         NaN
# 3       NaN      NaN        NaN           NaN     NaN         NaN
# 4       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN         0         NaN            NaN        NaN         NaN
# 1       NaN         0         NaN            NaN        NaN         NaN
# 2       NaN         0         NaN            NaN        NaN         NaN
# 3       NaN         1         NaN            NaN        NaN         NaN
# 4       NaN         1         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS        0         0         0        0     NaN
# 1     PGIS        0         1         1        1     NaN
# 2     PGIS       -9        -9         1        1     NaN
# 3     PGIS       -9        -9         1        1     NaN
# 4     PGIS       -9        -9         1        1     NaN

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# ### There are too many columns. Let´s check if we will use all of them.

# %%
# select some relevant columns 
df = df[['eventid','iyear','imonth','iday','region_txt','country_txt','city','latitude','longitude','success','suicide','attacktype1_txt','targtype1_txt','target1','natlty1_txt','gname','motive','weaptype1_txt','weapdetail','nkill','nwound','nhostkid']]

# %%
# % of columns without values
df.isna().sum() / len(df) * 100
# Out:
# eventid             0.000000
# iyear               0.000000
# imonth              0.000000
# iday                0.000000
# region_txt          0.000000
# country_txt         0.000000
# city                0.238867
# latitude            2.507554
# longitude           2.508104
# success             0.000000
# suicide             0.000000
# attacktype1_txt     0.000000
# targtype1_txt       0.000000
# target1             0.350045
# natlty1_txt         0.858050
# gname               0.000000
# motive             72.171984
# weaptype1_txt       0.000000
# weapdetail         37.244553
# nkill               5.676120
# nwound              8.977330
# nhostkid           92.530175
# dtype: float64

# %%
# visualizing if it has null values
missingno.matrix(df, figsize=(30,10))
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'region_txt', 'country_txt',
#        'city', 'latitude', 'longitude', 'success', 'suicide',
#        'attacktype1_txt', 'targtype1_txt', 'target1', 'natlty1_txt', 'gname',
#        'motive', 'weaptype1_txt', 'weapdetail', 'nkill', 'nwound', 'nhostkid'],
#       dtype='object')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday                   region_txt  \
# 0  197000000001   1970       7     2  Central America & Caribbean
# 1  197000000002   1970       0     0                North America
# 2  197001000001   1970       1     0               Southeast Asia
# 3  197001000002   1970       1     0               Western Europe
# 4  197001000003   1970       1     0                    East Asia
#
#           country_txt           city   latitude   longitude  success  suicide  \
# 0  Dominican Republic  Santo Domingo  18.456792  -69.951164        1        0
# 1              Mexico    Mexico city  19.371887  -99.086624        1        0
# 2         Philippines        Unknown  15.478598  120.599741        1        0
# 3              Greece         Athens  37.997490   23.762728        1        0
# 4               Japan        Fukouka  33.580412  130.396361        1        0
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                    target1         natlty1_txt  \
# 0             Julio Guzman  Dominican Republic
# 1  Nadine Chaval, daughter             Belgium
# 2                 Employee       United States
# 3             U.S. Embassy       United States
# 4           U.S. Consulate       United States
#
#                                 gname motive weaptype1_txt  weapdetail  nkill  \
# 0                              MANO-D    NaN       Unknown         NaN    1.0
# 1  23rd of September Communist League    NaN       Unknown         NaN    0.0
# 2                             Unknown    NaN       Unknown         NaN    1.0
# 3                             Unknown    NaN    Explosives   Explosive    NaN
# 4                             Unknown    NaN    Incendiary  Incendiary    NaN
#
#    nwound  nhostkid
# 0     0.0       NaN
# 1     0.0       1.0
# 2     0.0       NaN
# 3     NaN       NaN
# 4     NaN       NaN

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# - ### How many terrorist attacks it has in each city

# %%
df['city'].value_counts()
# Out:
# Unknown        9775
# Baghdad        7589
# Karachi        2652
# Lima           2359
# Mosul          2265
#                ...
# Chiringpara       1
# Vrbove            1
# Lungkiaban        1
# Akrabe            1
# Arnia             1
# Name: city, Length: 36674, dtype: int64

# %% [markdown]
# - ### How many terrorist attacks it has in each country

# %%
df['country_txt'].value_counts()
# Out:
# Iraq                24636
# Pakistan            14368
# Afghanistan         12731
# India               11960
# Colombia             8306
#                     ...
# New Hebrides            1
# Falkland Islands        1
# Vatican City            1
# St. Lucia               1
# International           1
# Name: country_txt, Length: 205, dtype: int64

# %% [markdown]
# - ### How many terrorist attacks it has in each Region

# %%
df['region_txt'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: region_txt, dtype: int64

# %% [markdown]
# - ### The name of the terrorist groups involved

# %%
df['gname'].unique()
# Out:
# array(['MANO-D', '23rd of September Communist League', 'Unknown', ...,
#        'Fatoni Warriors', 'Minorities of Metropolitan Attacks',
#        'Baloch Republican Party'], dtype=object)

# %% [markdown]
# - ### The weapons that are used using during the terrorism

# %%
df['weaptype1_txt'].unique()
# Out:
# array(['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
#        'Melee', 'Sabotage Equipment',
#        'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
#        'Fake Weapons', 'Radiological', 'Other', 'Biological'],
#       dtype=object)

# %% [markdown]
# - ### The type of attack used using during the terrorism

# %%
df['attacktype1_txt'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %% [markdown]
# ## Let's create some plots to analys

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'region_txt', 'country_txt',
#        'city', 'latitude', 'longitude', 'success', 'suicide',
#        'attacktype1_txt', 'targtype1_txt', 'target1', 'natlty1_txt', 'gname',
#        'motive', 'weaptype1_txt', 'weapdetail', 'nkill', 'nwound', 'nhostkid'],
#       dtype='object')

# %%
y = df['iyear'].groupby(df['iyear']).count()
x = y.index

plt.figure(figsize = (15,8))
plt.xticks(rotation = 45)
plt.title("Total of Terrorism per Year")
plt.xticks(x)
plt.bar(x,y,color="black")
plt.show()

# %% [markdown]
# - ### The year with more terrorist attacks was 2014

# %%
df_2014 = df[df['iyear'] == 2014]
y = df_2014['imonth'].groupby(df_2014['imonth']).count()
x = y.index

plt.xticks(rotation = 45)
plt.title("Total of Terrorism per Month in 2014")
plt.xticks(x)
plt.xlabel("Month")
plt.bar(x,y,color="black")
plt.show()

# %% [markdown]
# - ### The months with more terrorist attacks was July

# %%
y = df['nkill'].groupby(df['iyear']).sum()
x = y.index

plt.figure(figsize = (15,8))
plt.xticks(rotation = 45)
plt.title("Total of deaths caused by Terrorism per Year")
plt.xticks(x)
plt.xlabel("Year")
plt.bar(x,y,color="black")
plt.show()

# %% [markdown]
# - ### The year with more attacks was the year with more deaths as well

# %%
y = df['eventid'].groupby(df['region_txt']).count()
x = y.index

plt.figure(figsize = (10,8))
plt.title("Total of attacks per Region")

plt.xlabel("Attacks")
plt.barh(x,y,color="black")
plt.show()

# %% [markdown]
# - ### The Region with more attacks was Middle East & North Africa

# %%
y = df['eventid'].groupby(df['country_txt']).count()
y.sort_values(ascending=False, inplace=True)
x = y.index

plt.title("Top 10 Countries - terrorist attacks")

plt.xlabel("Attacks")
plt.barh(x[:10],y[:10],color="black")
plt.show()

# %% [markdown]
# - ### The Country that suffered more terrorist attacks was Iraq

# %%
# Here let´s check the attacks on 2014(the year with more attacks) on map using the longitude
filterData = df_2014 

# We are getting the required fields
reqFilterData = filterData.loc[:,'city':'longitude'] 
# drop NaN values in latitude and longitude
reqFilterData = reqFilterData.dropna() 
reqFilterDataList = reqFilterData.values.tolist()

# Show the data on the map using folium
map = folium.Map(location = [0, 30], tiles="Stamen Toner", zoom_start=2) # we can use tiles='CartoDB positron' 

# clustered marker
markerCluster = folium.plugins.MarkerCluster().add_to(map)
for point in range(0, len(reqFilterDataList)):
    folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]],
                  popup = reqFilterDataList[point][0]).add_to(markerCluster)
map

# %% [markdown]
# - ### When we visualize on the map is easier to see the countries that suffered more terrorist attacks. Middle East is the Region that receive more attacks comparing to all other regions in 2014.

# %%
df_2014_region = df_2014.groupby(['iyear','region_txt'])[['nkill','nwound','eventid']].agg({'nkill':'sum','nwound':'sum','eventid':'count'})
df_2014_region['%attack'] = df_2014_region['eventid'] / df_2014_region['eventid'].sum() * 100
df_2014_region['avgwounddeathperattack'] = (df_2014_region['nkill'] + df_2014_region['nwound']) / df_2014_region['eventid'] 
df_2014_region
# Out:
#                                      nkill   nwound  eventid    %attack  \
# iyear region_txt
# 2014  Australasia & Oceania            4.0      7.0        9   0.053245
#       Central America & Caribbean      5.0     65.0        5   0.029581
#       Central Asia                     5.0      7.0        9   0.053245
#       East Asia                      322.0    478.0       43   0.254393
#       Eastern Europe                1467.0   1329.0      962   5.691297
#       Middle East & North Africa   20080.0  22601.0     6939  41.051884
#       North America                   34.0     27.0       37   0.218896
#       South America                  157.0    355.0      283   1.674259
#       South Asia                    8358.0   9461.0     4998  29.568716
#       Southeast Asia                 702.0   1451.0     1082   6.401231
#       Sub-Saharan Africa           13351.0   5316.0     2321  13.731290
#       Western Europe                   5.0     31.0      215   1.271964
#
#                                    avgwounddeathperattack
# iyear region_txt
# 2014  Australasia & Oceania                      1.222222
#       Central America & Caribbean               14.000000
#       Central Asia                               1.333333
#       East Asia                                 18.604651
#       Eastern Europe                             2.906445
#       Middle East & North Africa                 6.150886
#       North America                              1.648649
#       South America                              1.809187
#       South Asia                                 3.565226
#       Southeast Asia                             1.989834
#       Sub-Saharan Africa                         8.042654
#       Western Europe                             0.167442

# %% [markdown]
# - ### Above we can see that Middle East & North Africa correspond 41% of all attacks in 2014 with an average of 6 person of death or wound per attack

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'region_txt', 'country_txt',
#        'city', 'latitude', 'longitude', 'success', 'suicide',
#        'attacktype1_txt', 'targtype1_txt', 'target1', 'natlty1_txt', 'gname',
#        'motive', 'weaptype1_txt', 'weapdetail', 'nkill', 'nwound', 'nhostkid'],
#       dtype='object')

# %%
y = df['eventid'].groupby(df['gname']).count()
y.sort_values(ascending=False, inplace=True)
x = y.index

plt.title("Top 10 Group responsable for the terrorist attacks")
plt.xlabel("Attacks")
plt.barh(x[:10],y[:10],color="black")
plt.show()

# getting the top 3 group with more numbers of attacks
top3_group = y.index[:3]

# %% [markdown]
# - ### Most attacks are from unconfirmed or unknown groups. Taliban group is responsible for 7478 attacks.

# %%
# Let´s check the top 3 groups. What kind of attack and weapon did they use
df_top3_group = df[df['gname'].isin(top3_group)]
df_top3_group = df_top3_group.groupby(['gname','attacktype1_txt','weaptype1_txt']).count().reset_index()
df_top3_group.sort_values(by='eventid', ascending=False).head(10)
# Out:
#                                            gname  \
# 86                                       Unknown
# 71                                       Unknown
# 79                                       Unknown
# 9    Islamic State of Iraq and the Levant (ISIL)
# 98                                       Unknown
# 40                                       Taliban
# 31                                       Taliban
# 119                                      Unknown
# 78                                       Unknown
# 136                                      Unknown
#
#                     attacktype1_txt weaptype1_txt  eventid  iyear  imonth  \
# 86                Bombing/Explosion    Explosives    46540  46540   46540
# 71                    Armed Assault      Firearms    14538  14538   14538
# 79                    Assassination      Firearms     6372   6372    6372
# 9                 Bombing/Explosion    Explosives     3643   3643    3643
# 98   Facility/Infrastructure Attack    Incendiary     3367   3367    3367
# 40                Bombing/Explosion    Explosives     2863   2863    2863
# 31                    Armed Assault      Firearms     1987   1987    1987
# 119     Hostage Taking (Kidnapping)      Firearms     1854   1854    1854
# 78                    Assassination    Explosives     1792   1792    1792
# 136                         Unknown       Unknown     1526   1526    1526
#
#       iday  approxdate  extended  resolution  country  country_txt  region  \
# 86   46540        3720     46540          13    46540        46540   46540
# 71   14538         581     14538          24    14538        14538   14538
# 79    6372         107      6372           4     6372         6372    6372
# 9     3643         887      3643           0     3643         3643    3643
# 98    3367          75      3367           4     3367         3367    3367
# 40    2863         145      2863           0     2863         2863    2863
# 31    1987         137      1987           2     1987         1987    1987
# 119   1854         101      1854         240     1854         1854    1854
# 78    1792          59      1792           0     1792         1792    1792
# 136   1526         119      1526           1     1526         1526    1526
#
#      region_txt  provstate   city  latitude  longitude  specificity  vicinity  \
# 86        46540      46455  46438     46045      46044        46539     46540
# 71        14538      14500  14355     14276      14276        14537     14538
# 79         6372       6335   6366      6269       6269         6372      6372
# 9          3643       3643   3643      3637       3637         3643      3643
# 98         3367       3355   3360      3329       3329         3367      3367
# 40         2863       2863   2849      2856       2856         2863      2863
# 31         1987       1987   1963      1986       1986         1987      1987
# 119        1854       1850   1850      1818       1818         1854      1854
# 78         1792       1789   1786      1772       1772         1792      1792
# 136        1526       1517   1517      1445       1445         1526      1526
#
#      location  summary  crit1  crit2  crit3  doubtterr  alternative  \
# 86      18827    36217  46540  46540  46540      46539         4537
# 71       5714    11400  14538  14538  14538      14538         3365
# 79       1359     2980   6372   6372   6372       6372         1036
# 9        1916     3643   3643   3643   3643       3643          685
# 98        900     2017   3367   3367   3367       3367          236
# 40       1225     2862   2863   2863   2863       2863          447
# 31        846     1987   1987   1987   1987       1987          359
# 119       642     1484   1854   1854   1854       1854          275
# 78        755     1277   1792   1792   1792       1792          124
# 136       307      832   1526   1526   1526       1526          382
#
#      alternative_txt  multiple  success  suicide  attacktype1  attacktype2  \
# 86              4537     46540    46540    46540        46540          511
# 71              3365     14538    14538    14538        14538          361
# 79              1036      6372     6372     6372         6372           28
# 9                685      3643     3643     3643         3643          122
# 98               236      3367     3367     3367         3367           27
# 40               447      2863     2863     2863         2863          179
# 31               359      1987     1987     1987         1987           67
# 119              275      1854     1854     1854         1854          308
# 78               124      1792     1792     1792         1792            6
# 136              382      1526     1526     1526         1526            0
#
#      attacktype2_txt  attacktype3  attacktype3_txt  targtype1  targtype1_txt  \
# 86               511           22               22      46540          46540
# 71               361            8                8      14538          14538
# 79                28            2                2       6372           6372
# 9                122            1                1       3643           3643
# 98                27            0                0       3367           3367
# 40               179            0                0       2863           2863
# 31                67            1                1       1987           1987
# 119              308           20               20       1854           1854
# 78                 6            0                0       1792           1792
# 136                0            0                0       1526           1526
#
#      targsubtype1  targsubtype1_txt  corp1  target1  natlty1  natlty1_txt  \
# 86          41683             41683  35644    46392    45854        45854
# 71          14220             14220  11651    14513    14494        14494
# 79           6078              6078   5595     6358     6336         6336
# 9            3419              3419   3643     3643     3638         3638
# 98           3230              3230   2185     3356     3335         3335
# 40           2605              2605   2651     2857     2640         2640
# 31           1970              1970   1877     1984     1985         1985
# 119          1752              1752   1612     1851     1849         1849
# 78           1765              1765   1586     1792     1789         1789
# 136          1460              1460   1089     1521     1496         1496
#
#      targtype2  targtype2_txt  targsubtype2  targsubtype2_txt  corp2  target2  \
# 86        2769           2769          2667              2667   2544     2739
# 71         696            696           669               669    615      693
# 79         155            155           141               141    134      152
# 9          494            494           493               493    494      494
# 98          79             79            76                76     47       79
# 40         501            501           498               498    479      499
# 31         218            218           215               215    197      217
# 119        139            139           122               122    123      139
# 78         105            105           102               102     98      104
# 136         44             44            38                38     38       41
#
#      natlty2  natlty2_txt  targtype3  targtype3_txt  targsubtype3  \
# 86      2662         2662        182            182           166
# 71       667          667         54             54            51
# 79       146          146         11             11            10
# 9        492          492         56             56            54
# 98        77           77         16             16            16
# 40       493          493         59             59            58
# 31       214          214         16             16            16
# 119      131          131         24             24            22
# 78       102          102          6              6             6
# 136       41           41          6              6             5
#
#      targsubtype3_txt  corp3  target3  natlty3  natlty3_txt  gsubname  gname2  \
# 86                166    159      181      175          175         0       1
# 71                 51     47       54       51           51         0       0
# 79                 10      9       11       11           11         0       0
# 9                  54     56       56       56           56       423      37
# 98                 16      6       16       11           11         0       0
# 40                 58     57       60       58           58         2      35
# 31                 16     14       16       16           16         5      19
# 119                22     23       24       24           24         0       0
# 78                  6      5        6        6            6         0       0
# 136                 5      6        6        5            5         1       0
#
#      gsubname2  gname3  gsubname3  motive  guncertain1  guncertain2  \
# 86           0       0          0   13916        46539            1
# 71           0       0          0    5406        14537            0
# 79           0       0          0    1151         6372            0
# 9            4       6          0     448         3643           37
# 98           0       0          0    1144         3367            0
# 40           0       0          0     828         2863           35
# 31           0       4          0     472         1987           19
# 119          0       0          0     684         1854            0
# 78           0       0          0     590         1792            0
# 136          0       0          0     248         1526            0
#
#      guncertain3  individual  nperps  nperpcap  claimed  claimmode  \
# 86             0       46540   32206     35067    36217        100
# 71             0       14538   10072     10963    11400         45
# 79             0        6372    3442      2885     2980         13
# 9              6        3643    3643      3643     3643       1833
# 98             0        3367    1844      1956     2017         30
# 40             0        2863    2639      2801     2862       1420
# 31             4        1987    1840      1953     1987       1058
# 119            0        1854    1348      1399     1484         20
# 78             0        1792    1229      1260     1277          3
# 136            0        1526     835       812      832          1
#
#      claimmode_txt  claim2  claimmode2  claimmode2_txt  claim3  claimmode3  \
# 86             100       2           1               1       1           1
# 71              45       0           0               0       0           0
# 79              13       0           0               0       0           0
# 9             1833      37          12              12       6           1
# 98              30       0           0               0       0           0
# 40            1420      35          15              15       0           0
# 31            1058      19           4               4       4           1
# 119             20       1           0               0       0           0
# 78               3       0           0               0       0           0
# 136              1       1           0               0       0           0
#
#      claimmode3_txt  compclaim  weaptype1  weapsubtype1  weapsubtype1_txt  \
# 86                1        555      46540         46532             46532
# 71                0        215      14538         14534             14534
# 79                0         47       6372          6371              6371
# 9                 1         12       3643          3643              3643
# 98                0         23       3367          2159              2159
# 40                0        174       2863          2863              2863
# 31                1         97       1987          1987              1987
# 119               0         50       1854          1853              1853
# 78                0         11       1792          1792              1792
# 136               0          5       1526             0                 0
#
#      weaptype2  weaptype2_txt  weapsubtype2  weapsubtype2_txt  weaptype3  \
# 86        1081           1081          1032              1032        128
# 71         623            623           569               569         53
# 79         162            162           152               152          8
# 9          481            481           261               261         86
# 98         132            132            80                80          5
# 40         261            261           223               223         58
# 31          93             93            89                89          3
# 119        127            127           113               113         11
# 78          87             87            87                87          5
# 136          1              1             0                 0          0
#
#      weaptype3_txt  weapsubtype3  weapsubtype3_txt  weaptype4  weaptype4_txt  \
# 86             128           116               116          3              3
# 71              53            48                48          1              1
# 79               8             8                 8          1              1
# 9               86            65                65          0              0
# 98               5             4                 4          0              0
# 40              58            58                58          1              1
# 31               3             3                 3          0              0
# 119             11             8                 8          0              0
# 78               5             5                 5          0              0
# 136              0             0                 0          0              0
#
#      weapsubtype4  weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  \
# 86              3                 3       31155  45135    36360     36101
# 71              2                 2        6983  14149    11412     11231
# 79              1                 1        4091   6361     3044      3021
# 9               0                 0        1646   3507     3643      3554
# 98              0                 0        2317   3191     2037      2013
# 40              1                 1        1903   2844     2846      2829
# 31              0                 0         288   1939     1980      1848
# 119             0                 0         676   1383     1506      1479
# 78              0                 0        1401   1778     1293      1293
# 136             0                 0         216   1420      844       812
#
#      nwound  nwoundus  nwoundte  property  propextent  propextent_txt  \
# 86    44614     36293     35936     46540       18958           18958
# 71    13792     11402     11044     14538        3757            3757
# 79     6252      3032      3005      6372         731             731
# 9      3368      3643      3463      3643        1339            1339
# 98     3180      2037      2007      3367        2352            2352
# 40     2796      2812      2803      2863        1652            1652
# 31     1818      1975      1723      1987         448             448
# 119    1329      1504      1463      1854         210             210
# 78     1763      1294      1288      1792         949             949
# 136    1378       846       788      1526         217             217
#
#      propvalue  propcomment  ishostkid  nhostkid  nhostkidus  nhours  ndays  \
# 86       10622        20066      46521        26          26      10     14
# 71        1827         3871      14534       140         136      47     62
# 79         558          862       6372        66          66      37     26
# 9         1339         1966       3643         0           0       0      0
# 98        1573         1867       3358         8           7       1      6
# 40        1241         1798       2863         1           1       0      1
# 31         323          635       1987        22          21       8     15
# 119        135          246       1854      1781        1772     381   1334
# 78         562          968       1792         0           0       0      0
# 136        103          257       1526         9           9       1      1
#
#      divert  kidhijcountry  ransom  ransomamt  ransomamtus  ransompaid  \
# 86        1              1   10562          4            0           0
# 71        3              7    3267          2            0           1
# 79        2              4    3462          0            0           0
# 9         0              0       0          0            0           0
# 98        0              1    1396          0            0           0
# 40        0              0       2          0            0           0
# 31        0              2      25          0            0           0
# 119      21            389    1764        136           80         102
# 78        0              0     516          1            0           0
# 136       0              5     704          0            0           0
#
#      ransompaidus  ransomnote  hostkidoutcome  hostkidoutcome_txt  nreleased  \
# 86              0           0              22                  22         20
# 71              1           1              88                  88         68
# 79              0           0              61                  61         61
# 9               0           0               0                   0          0
# 98              0           0               5                   5          5
# 40              0           0               1                   1          1
# 31              0           0              22                  22         22
# 119            79          70            1572                1572       1491
# 78              0           0               0                   0          0
# 136             0           0               1                   1          2
#
#      addnotes  scite1  scite2  scite3  dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 86       6558   36196   21048   10264     46540    46540     46540     46540
# 71       1664   11397    6637    2983     14538    14538     14538     14538
# 79        496    2980    1866     936      6372     6372      6372      6372
# 9        1408    3643    2949    1990      3643     3643      3643      3643
# 98        211    2017    1192     469      3367     3367      3367      3367
# 40        904    2860    2300    1486      2863     2863      2863      2863
# 31        736    1986    1395     740      1987     1987      1987      1987
# 119       352    1482     980     546      1854     1854      1854      1854
# 78        201    1277     953     527      1792     1792      1792      1792
# 136        93     831     259      81      1526     1526      1526      1526
#
#      INT_ANY  related
# 86     46540     5029
# 71     14538      604
# 79      6372       64
# 9       3643     1333
# 98      3367      622
# 40      2863      303
# 31      1987      475
# 119     1854       78
# 78      1792       49
# 136     1526       80

# %%
df_Baghdad = df#[df['city'] == 'Baghdad']
df_Baghdad = df_Baghdad.groupby(['city','gname']).count().reset_index()
df_Baghdad.sort_values(by='eventid', ascending=False).head(10)
# Out:
#                city                                             gname  \
# 4450        Baghdad                                           Unknown
# 50918       Unknown                                           Unknown
# 23486       Karachi                                           Unknown
# 33091         Mosul                                           Unknown
# 28299          Lima                                 Shining Path (SL)
# 6681        Belfast                       Irish Republican Army (IRA)
# 32616     Mogadishu                                        Al-Shabaab
# 25382        Kirkuk                                           Unknown
# 43572      Santiago                                           Unknown
# 43052  San Salvador  Farabundo Marti National Liberation Front (FMLN)
#
#        eventid  iyear  imonth  iday  approxdate  extended  resolution  \
# 4450      6535   6535    6535  6535         819      6535          19
# 50918     3756   3756    3756  3756         371      3756          70
# 23486     2125   2125    2125  2125          40      2125           5
# 33091     1534   1534    1534  1534         184      1534           4
# 28299     1408   1408    1408  1408           1      1408           3
# 6681      1024   1024    1024  1024           0      1024           3
# 32616      952    952     952   952          25       952           7
# 25382      815    815     815   815          47       815           2
# 43572      705    705     705   705           1       705           2
# 43052      697    697     697   697           0       697           4
#
#        country  country_txt  region  region_txt  provstate  latitude  \
# 4450      6535         6535    6535        6535       6535      6535
# 50918     3756         3756    3756        3756       3750      2947
# 23486     2125         2125    2125        2125       2125      2125
# 33091     1534         1534    1534        1534       1534      1534
# 28299     1408         1408    1408        1408       1408      1408
# 6681      1024         1024    1024        1024       1024      1024
# 32616      952          952     952         952        952       951
# 25382      815          815     815         815        815       815
# 43572      705          705     705         705        705       705
# 43052      697          697     697         697        696       697
#
#        longitude  specificity  vicinity  location  summary  crit1  crit2  \
# 4450        6535         6535      6535      5272     6509   6535   6535
# 50918       2947         3756      3756       764     2453   3756   3756
# 23486       2125         2125      2125      1026     1247   2125   2125
# 33091       1534         1534      1534      1096     1532   1534   1534
# 28299       1408         1408      1408         4        6   1408   1408
# 6681        1024         1024      1024        11       11   1024   1024
# 32616        951          951       952       723      952    952    952
# 25382        815          815       815       527      813    815    815
# 43572        705          705       705        19       45    705    705
# 43052        697          697       697         0        0    697    697
#
#        crit3  doubtterr  alternative  alternative_txt  multiple  success  \
# 4450    6535       6535          320              320      6535     6535
# 50918   3756       3756          766              766      3756     3756
# 23486   2125       2125          269              269      2125     2125
# 33091   1534       1534          232              232      1534     1534
# 28299   1408       1408           55               55      1408     1408
# 6681    1024       1024          250              250      1024     1024
# 32616    952        952          226              226       952      952
# 25382    815        815           98               98       815      815
# 43572    705        705           22               22       705      705
# 43052    697        697           92               92       697      697
#
#        suicide  attacktype1  attacktype1_txt  attacktype2  attacktype2_txt  \
# 4450      6535         6535             6535           58               58
# 50918     3756         3756             3756           73               73
# 23486     2125         2125             2125           14               14
# 33091     1534         1534             1534           28               28
# 28299     1408         1408             1408            0                0
# 6681      1024         1024             1024            1                1
# 32616      952          952              952           42               42
# 25382      815          815              815           12               12
# 43572      705          705              705            1                1
# 43052      697          697              697            0                0
#
#        attacktype3  attacktype3_txt  targtype1  targtype1_txt  targsubtype1  \
# 4450             0                0       6535           6535          6196
# 50918            3                3       3756           3756          3288
# 23486            1                1       2125           2125          1922
# 33091            1                1       1534           1534          1373
# 28299            0                0       1408           1408          1361
# 6681             0                0       1024           1024           964
# 32616            4                4        952            952           925
# 25382            0                0        815            815           786
# 43572            0                0        705            705           672
# 43052            0                0        697            697           675
#
#        targsubtype1_txt  corp1  target1  natlty1  natlty1_txt  targtype2  \
# 4450               6196   5405     6514     6530         6530        349
# 50918              3288   3058     3724     3558         3558        171
# 23486              1922   1885     2120     2084         2084         63
# 33091              1373   1253     1531     1532         1532        121
# 28299              1361    687     1398     1405         1405         20
# 6681                964    605     1021     1021         1021         16
# 32616               925    906      952      932          932        162
# 25382               786    693      813      810          810         37
# 43572               672    248      703      702          702          6
# 43052               675    376      694      697          697          2
#
#        targtype2_txt  targsubtype2  targsubtype2_txt  corp2  target2  natlty2  \
# 4450             349           331               331    312      342      327
# 50918            171           156               156    152      168      159
# 23486             63            63                63     56       63       61
# 33091            121           119               119    114      120      116
# 28299             20            18                18      5       18       18
# 6681              16            16                16     15       16       16
# 32616            162           161               161    160      162      162
# 25382             37            37                37     37       37       33
# 43572              6             4                 4      5        5        5
# 43052              2             2                 2      2        2        2
#
#        natlty2_txt  targtype3  targtype3_txt  targsubtype3  targsubtype3_txt  \
# 4450           327         27             27            24                24
# 50918          159         18             18            15                15
# 23486           61          4              4             4                 4
# 33091          116          5              5             5                 5
# 28299           18         11             11            11                11
# 6681            16          0              0             0                 0
# 32616          162         17             17            16                16
# 25382           33          5              5             5                 5
# 43572            5          0              0             0                 0
# 43052            2          0              0             0                 0
#
#        corp3  target3  natlty3  natlty3_txt  gsubname  gname2  gsubname2  \
# 4450      21       27       26           26         0       0          0
# 50918     13       18       16           16         0       0          0
# 23486      4        4        4            4         0       0          0
# 33091      5        5        5            5         0       0          0
# 28299      0       11       11           11         0       4          0
# 6681       0        0        0            0         1       1          0
# 32616     17       17       17           17         3       8          0
# 25382      5        5        5            5         0       0          0
# 43572      0        0        0            0         0       0          0
# 43052      0        0        0            0       155       0          0
#
#        gname3  gsubname3  motive  guncertain1  guncertain2  guncertain3  \
# 4450        0          0    3198         6535            0            0
# 50918       0          0     748         3756            0            0
# 23486       0          0     564         2125            0            0
# 33091       0          0     738         1534            0            0
# 28299       0          0       5         1408            4            0
# 6681        0          0      11         1024            1            0
# 32616       0          0     222          952            2            0
# 25382       0          0     496          815            0            0
# 43572       0          0      35          705            0            0
# 43052       0          0       0          697            0            0
#
#        individual  nperps  nperpcap  claimed  claimmode  claimmode_txt  \
# 4450         6535    5399      6185     6509          6              6
# 50918        3756    2152      2323     2453         13             13
# 23486        2125    1242      1236     1247         12             12
# 33091        1534    1402      1492     1532          1              1
# 28299        1408     141         6        6          1              1
# 6681         1024      61        10       11          0              0
# 32616         952     947       952      952        402            402
# 25382         815     652       773      813          1              1
# 43572         705      89        42       45          3              3
# 43052         697      29         0        0          0              0
#
#        claim2  claimmode2  claimmode2_txt  claim3  claimmode3  claimmode3_txt  \
# 4450        1           0               0       0           0               0
# 50918       0           0               0       0           0               0
# 23486       0           0               0       0           0               0
# 33091       0           0               0       0           0               0
# 28299       0           0               0       0           0               0
# 6681        1           0               0       0           0               0
# 32616       9           4               4       0           0               0
# 25382       0           0               0       0           0               0
# 43572       0           0               0       0           0               0
# 43052       0           0               0       0           0               0
#
#        compclaim  weaptype1  weaptype1_txt  weapsubtype1  weapsubtype1_txt  \
# 4450         179       6535           6535          6507              6507
# 50918         63       3756           3756          3172              3172
# 23486          7       2125           2125          1777              1777
# 33091         18       1534           1534          1513              1513
# 28299          0       1408           1408          1265              1265
# 6681           1       1024           1024           832               832
# 32616         17        952            952           893               893
# 25382         20        815            815           794               794
# 43572          4        705            705           628               628
# 43052          0        697            697           624               624
#
#        weaptype2  weaptype2_txt  weapsubtype2  weapsubtype2_txt  weaptype3  \
# 4450          80             80            76                76          9
# 50918        167            167           148               148         10
# 23486         56             56            52                52          1
# 33091         37             37            36                36          2
# 28299         56             56            53                53          4
# 6681          32             32            32                32          2
# 32616         73             73            72                72         15
# 25382         15             15            15                15          1
# 43572         23             23            20                20          1
# 43052         56             56            49                49          9
#
#        weaptype3_txt  weapsubtype3  weapsubtype3_txt  weaptype4  \
# 4450               9             9                 9          0
# 50918             10             8                 8          0
# 23486              1             1                 1          0
# 33091              2             2                 2          0
# 28299              4             4                 4          0
# 6681               2             2                 2          0
# 32616             15            14                14          0
# 25382              1             1                 1          0
# 43572              1             1                 1          1
# 43052              9             9                 9          3
#
#        weaptype4_txt  weapsubtype4  weapsubtype4_txt  weapdetail  nkill  \
# 4450               0             0                 0        2941   6456
# 50918              0             0                 0        1967   3505
# 23486              0             0                 0        1108   2110
# 33091              0             0                 0         959   1523
# 28299              0             1                 1        1367   1250
# 6681               0             0                 0         987    992
# 32616              0             0                 0         465    841
# 25382              0             0                 0         421    806
# 43572              1             1                 1         665    547
# 43052              3             3                 3         683    618
#
#        nkillus  nkillter  nwound  nwoundus  nwoundte  property  propextent  \
# 4450      6424      6381    6360      6393      6336      6535        2645
# 50918     2469      2443    3419      2474      2415      3756        1009
# 23486     1252      1249    2058      1250      1243      2125         406
# 33091     1520      1492    1500      1512      1491      1534         518
# 28299       57        32    1245        58        33      1408         443
# 6681        31        39     674        32        26      1024         181
# 32616      952       878     820       952       876       952         347
# 25382      806       787     793       804       783       815         379
# 43572       47        57     547        47        57       705         149
# 43052        8         9     616         8         6       697         375
#
#        propextent_txt  propvalue  propcomment  ishostkid  nhostkid  \
# 4450             2645       1089         3724       6535       116
# 50918            1009        666          897       3756       353
# 23486             406        301          559       2125        58
# 33091             518        202          689       1534        28
# 28299             443        334           55       1408        12
# 6681              181        108           22       1024        24
# 32616             347        283          534        952        29
# 25382             379        148          442        815        29
# 43572             149         74          182        705        14
# 43052             375        294           10        697        25
#
#        nhostkidus  nhours  ndays  divert  kidhijcountry  ransom  ransomamt  \
# 4450          115      15     98       5             15     159          6
# 50918         350      66    199       7            156    1503         27
# 23486          58      14     29       0             23     914          3
# 33091          27      10     17       1              4      46          4
# 28299          12       5      4       0              3    1402          1
# 6681           24       6      4       0             18    1013          1
# 32616          29       9     20       0              0      30          1
# 25382          29       4     25       0              3      37          1
# 43572          14       2      2       0              9     660          1
# 43052          25       7      3       0              5     697          1
#
#        ransomamtus  ransompaid  ransompaidus  ransomnote  hostkidoutcome  \
# 4450             4           4             4           3             116
# 50918            7          11             6           6             250
# 23486            1           1             1           0              43
# 33091            3           3             3           2              26
# 28299            0           0             0           0               3
# 6681             0           0             0           0              15
# 32616            1           1             1           0              28
# 25382            0           0             0           0              29
# 43572            0           1             0           0               7
# 43052            0           0             0           0               2
#
#        hostkidoutcome_txt  nreleased  addnotes  scite1  scite2  scite3  \
# 4450                  116        101      1129    6507    3580    1708
# 50918                 250        231       303    2452     989     428
# 23486                  43         41       235    1247     800     429
# 33091                  26         26       168    1531     867     372
# 28299                   3          1         3       6       2       2
# 6681                   15          4         2      11       8       5
# 32616                  28         29       259     952     713     449
# 25382                  29         28       128     813     498     227
# 43572                   7          5        19      45      23       7
# 43052                   2          3         0       0       0       0
#
#        dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 4450       6535     6535      6535      6535     6535      389
# 50918      3756     3756      3756      3756     3756      311
# 23486      2125     2125      2125      2125     2125      124
# 33091      1534     1534      1534      1534     1534      157
# 28299      1408     1408      1408      1408     1408      462
# 6681       1024     1024      1024      1024     1024      148
# 32616       952      952       952       952      952      152
# 25382       815      815       815       815      815       86
# 43572       705      705       705       705      705       86
# 43052       697      697       697       697      697      223

# %% [markdown]
# - ### If we take a look in the top 3 group we can observe that the most common type of attack used were Bombing/Explosion(explosives) and Armed Assault(firearms).

# %% [markdown]
# ## Conclusion:
# ### With a quick analysis of the dataset we observe:
# - Year with more attacks and deaths: 2014
# - Region with more attacks: Middle East
# - Country with more attacks: Iraq
# - City with more attacks: Baghdad
# - Explosives and Firearms were the most common weapons used
# - The terrorist group with more attacks that was identified was Taliban
#
# ### The year 1993 has no information
